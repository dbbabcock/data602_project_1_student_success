# %% [markdown]
# <h3>This data was generated by: <a>http://roycekimmons.com/tools/generated_data/exams</a><br>
# <br>
# The data is fictional and only being used for modeling purposes.
# <br>
# <br>
# In order to create a larger training dataset, I downloaded 10 batches of of the large sample (1,000 rows). Each batch is randomly generated on the fly, so each one is different. In this notebook, I combine those into a single 10,000 row CSV file to use for the rest of the project.
# <br>
# <br>
# I also use another 10 batches of separate data to create a dataset for model testing.

# %%
import glob
import pandas as pd
print('Pandas version used: ' + pd.__version__)
# Out:
# Pandas version used: 1.0.5

# %%
# Find all of the files in this directory with the .csv format
all_exam_files = glob.glob('../Datasets/training_data_files/*.csv')

# %%
# Make sure we got all of the correct files:
all_exam_files
# Out:
# ['../Datasets/training_data_files\\exams_1.csv',
#  '../Datasets/training_data_files\\exams_10.csv',
#  '../Datasets/training_data_files\\exams_2.csv',
#  '../Datasets/training_data_files\\exams_3.csv',
#  '../Datasets/training_data_files\\exams_4.csv',
#  '../Datasets/training_data_files\\exams_5.csv',
#  '../Datasets/training_data_files\\exams_6.csv',
#  '../Datasets/training_data_files\\exams_7.csv',
#  '../Datasets/training_data_files\\exams_8.csv',
#  '../Datasets/training_data_files\\exams_9.csv']

# %%
# Read each of the files into a dataframe and then concatenate the dataframes together:
stu_perf_raw = pd.concat(pd.read_csv(file) for file in all_exam_files)

# %%
# Reset the index so that is goes from 0->9999 instead of 0->99 10 times:
stu_perf_raw.reset_index(drop=True, inplace=True)

# %%
# Final check before saving the combined file:
stu_perf_raw
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 0       male        group B            some high school      standard
# 1     female        group B            some high school  free/reduced
# 2       male        group B          associate's degree      standard
# 3       male        group C            some high school      standard
# 4     female        group C                 high school      standard
# ...      ...            ...                         ...           ...
# 9995    male        group B          associate's degree  free/reduced
# 9996    male        group A                some college  free/reduced
# 9997  female        group E                some college  free/reduced
# 9998    male        group C                some college  free/reduced
# 9999    male        group C          associate's degree      standard
#
#      test preparation course  math score  reading score  writing score
# ...

# %%
# Save the new csv file to the Datasets folder:
stu_perf_raw.to_csv("../Datasets/stu_perf_raw.csv", index=False)

# %% [markdown]
# <h3>Now to create the test dataset:

# %%
# Find all of the files in this directory with the .csv format
all_test_files = glob.glob('../Datasets/test_data_files/*.csv')

# %%
all_test_files
# Out:
# ['../Datasets/test_data_files\\exams (1).csv',
#  '../Datasets/test_data_files\\exams (2).csv',
#  '../Datasets/test_data_files\\exams (3).csv',
#  '../Datasets/test_data_files\\exams (4).csv',
#  '../Datasets/test_data_files\\exams (5).csv',
#  '../Datasets/test_data_files\\exams (6).csv',
#  '../Datasets/test_data_files\\exams (7).csv',
#  '../Datasets/test_data_files\\exams (8).csv',
#  '../Datasets/test_data_files\\exams (9).csv',
#  '../Datasets/test_data_files\\exams.csv']

# %%
# Read each of the files into a dataframe and then concatenate the dataframes together:
test_data_raw = pd.concat(pd.read_csv(file) for file in all_test_files)

# %%
# Reset the index so that is goes from 0->9999 instead of 0->99 10 times:
test_data_raw.reset_index(drop=True, inplace=True)

# %%
test_data_raw
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 0       male        group D          associate's degree  free/reduced
# 1     female        group C           bachelor's degree      standard
# 2       male        group C          associate's degree  free/reduced
# 3     female        group B                some college  free/reduced
# 4       male        group E                some college      standard
# ...      ...            ...                         ...           ...
# 9995    male        group E            some high school      standard
# 9996  female        group E                some college      standard
# 9997    male        group C                some college      standard
# 9998  female        group B            some high school  free/reduced
# 9999    male        group D                 high school      standard
#
#      test preparation course  math score  reading score  writing score
# ...

# %%
# Save the new test csv file to the Datasets folder:
test_data_raw.to_csv("../Datasets/test_data_raw.csv", index=False)
