# %%
import pandas as pd
print("Pandas version: " + pd.__version__)
# Out:
# Pandas version: 1.0.5

# %%
# Read in the dataframe:
covid_df = pd.read_csv("latestdata.csv", low_memory=False)

# %%
# Check out the head of the data and see if there are any obvious candidates to drop:
covid_df.head()
# Out:
#             ID  age     sex            city   province    country   latitude  \
# 0      000-1-1  NaN    male        Shek Lei  Hong Kong      China  22.365019
# 1     000-1-10   78    male      Vo Euganeo     Veneto      Italy  45.297748
# 2    000-1-100   61  female             NaN        NaN  Singapore   1.353460
# 3   000-1-1000  NaN     NaN  Zhengzhou City      Henan      China  34.629310
# 4  000-1-10000  NaN     NaN  Pingxiang City    Jiangxi      China  27.513560
#
#     longitude geo_resolution date_onset_symptoms  ... date_death_or_discharge  \
# 0  114.133808          point                 NaN  ...                     NaN
# 1   11.658382          point                 NaN  ...              22.02.2020
# 2  103.815100         admin0                 NaN  ...              17.02.2020
# 3  113.468000         admin2                 NaN  ...                     NaN
# 4  113.902900         admin2                 NaN  ...                     NaN
#
#   notes_for_discussion     location admin3          admin2     admin1  \
# 0                  NaN     Shek Lei    NaN             NaN  Hong Kong
# 1                  NaN  Vo' Euganeo    NaN             NaN     Veneto
# 2                  NaN          NaN    NaN             NaN        NaN
# 3                  NaN          NaN    NaN  Zhengzhou City      Henan
# 4                  NaN          NaN    NaN  Pingxiang City    Jiangxi
#
#   country_new admin_id  data_moderator_initials travel_history_binary
# 0       China   8029.0                      NaN                   NaN
# 1       Italy   8954.0                      NaN                   NaN
# 2   Singapore    200.0                      NaN                   NaN
# 3       China  10091.0                      NaN                   NaN
# 4       China   7060.0                      NaN                   NaN
#
# [5 rows x 33 columns]

# %%
# See the data types we are dealing with and how many rows/columns overall. Plus the names of the columns.
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2676311 entries, 0 to 2676310
# Data columns (total 33 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   ID                        object
#  1   age                       object
#  2   sex                       object
#  3   city                      object
#  4   province                  object
#  5   country                   object
#  6   latitude                  float64
#  7   longitude                 float64
#  8   geo_resolution            object
#  9   date_onset_symptoms       object
#  10  date_admission_hospital   object
#  11  date_confirmation         object
#  12  symptoms                  object
#  13  lives_in_Wuhan            object
#  14  travel_history_dates      object
#  15  travel_history_location   object
#  16  reported_market_exposure  object
#  17  additional_information    object
#  18  chronic_disease_binary    bool
#  19  chronic_disease           object
#  20  source                    object
#  21  sequence_available        object
#  22  outcome                   object
#  23  date_death_or_discharge   object
#  24  notes_for_discussion      object
#  25  location                  object
#  26  admin3                    object
#  27  admin2                    object
#  28  admin1                    object
#  29  country_new               object
#  30  admin_id                  float64
#  31  data_moderator_initials   object
#  32  travel_history_binary     object
# dtypes: bool(1), float64(3), object(29)
# memory usage: 655.9+ MB

# %% [markdown]
# <h3>There are a ton of rows (over 2 and a half million) here and a lot of columns (33). Juding by the names of some columns and the head of the dataframe, a lot of these are not going to be useful or are full of NaN values. I'll start by going through the columns and seeing what is useful and what can be dropped.

# %%
# Let's see how many of the values are NaN values. This will help us decide which columns to drop:
covid_df.isna().sum()
# Out:
# ID                                0
# age                         2098293
# sex                         2096154
# city                         977681
# province                     452664
# country                         115
# latitude                         61
# longitude                        61
# geo_resolution                   61
# date_onset_symptoms         2414712
# date_admission_hospital     2560100
# date_confirmation            108489
# symptoms                    2674259
# lives_in_Wuhan              2671973
# travel_history_dates        2673700
# travel_history_location     2667089
# reported_market_exposure    2675242
# additional_information      2630456
# chronic_disease_binary            0
# chronic_disease             2676096
# source                       566964
# sequence_available          2676299
# outcome                     2368929
# date_death_or_discharge     2673163
# notes_for_discussion        2675671
# location                    2662935
# admin3                      2595877
# admin2                      1850257
# admin1                      1418753
# country_new                   30553
# admin_id                         61
# data_moderator_initials      933328
# travel_history_binary         65579
# dtype: int64

# %% [markdown]
# <h3>There are a tremendous amnount of NaN values which will present a lot of issues. We will likely have to drop most rows in order to craft a useful dataset for the models.

# %%
# I think we can immediately get rid of the extra geospatial information and the admin/data mod columns:
covid_df_clean = covid_df.drop(["latitude","longitude","geo_resolution","admin3","admin2","admin1",
                                "admin_id","data_moderator_initials"], axis=1)

# %%
# Let's see what information is in the notes column. It probably will not be useful for this project
# since I am not doing text analysis:
covid_df_notes = covid_df["notes_for_discussion"]
covid_df_notes.dropna(inplace=True)
covid_df_notes.values
# Out:
# array(['https://www.google.com/maps/place/Zhenlai+County,+Baicheng,+Jilin,+China/@45.9549881,122.8772653,9z/data=!3m1!4b1!4m5!3m4!1s0x5e6a4c6a8ea66823:0xfb96317ca7cfd392!8m2!3d45.847435!4d123.1998901',
#        'https://new.qq.com/omn/20200215/20200215A0LD4100.html',
#        'https://new.qq.com/omn/20200215/20200215A0LD4100.html',
#        'https://www.google.com/maps/search/%E4%BD%8F%E5%9D%80%E4%B8%BA%E9%95%BF%E6%98%A5%E5%B8%82%E9%AB%98%E6%96%B0%E5%8C%BA%E8%9E%8D%E5%88%9B%E4%B8%8A%E5%9F%8E/@43.8296097,125.2592395,16z/data=!3m1!4b1?hl=en',
#        'google.com/maps/place/Luzhou,+Sichuan,+China/@28.8805475,105.3853199,12z/data=!3m1!4b1!4m5!3m4!1s0x36ebaab481693e8d:0x57ee20f6402d239e!8m2!3d28.871569!4d105.44174',
#        'https://www.zjwjw.gov.cn/art/2020/2/3/art_1202101_41869217.html',
#        'I believe is Cremona, not Codogno',
#        'https://www.cbc.ca/news/canada/british-columbia/bc-coronavirus-flight-montreal-vancouver-1.5473283',
#        'possible double count',
#        'Possible double count of Diamond Princess cases',
#        'Possible double count of Diamond Princess cases',
#        'Possible double count of Diamond Princess cases',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd', 'Could be some cases from 23rd',
#        'Could be some cases from 23rd',
#        'Most details from listening to LA County Public Health Dept Press Conference live',
#        'https://www.mhlw.go.jp/stf/newpage_09079.html',
#        'https://www.mhlw.go.jp/stf/newpage_08906.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html Initial district extraction seems incorrect',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html Initial district extraction seems incorrect',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html Initial district extraction seems incorrect',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'Travel to Cebu and Dumaguete also', "can't find original source",
#        'https://mp.weixin.qq.com/s?__biz=MjM5MTg5OTM0Ng==&mid=2651448627&idx=1&sn=e26391f0e764bfd4fc2a9a1bc15502ff&chksm=bd53ce8e8a2447985560b9a62b2a5f567693ac25032b0209cc489c49d91862fd480e4664094e&token=566312186&lang=zh_CN#rd',
#        'https://mp.weixin.qq.com/s?__biz=MjM5MTg5OTM0Ng==&mid=2651448627&idx=1&sn=e26391f0e764bfd4fc2a9a1bc15502ff&chksm=bd53ce8e8a2447985560b9a62b2a5f567693ac25032b0209cc489c49d91862fd480e4664094e&token=566312186&lang=zh_CN#rd',
#        'https://www.newsfirst.lk/2020/01/27/breaking-news-confirmed-case-of-coronavirus-in-sri-lanka/',
#        'Possible duplicate from Diamond Princess',
#        'https://www.preprints.org/manuscript/202002.0399/v1',
#        'https://www.preprints.org/manuscript/202002.0399/v1',
#        'had dinner with 3 patients diagnosed on January 31',
#        'has been working in Wuhan for a long time',
#        'https://www.mhlw.go.jp/stf/newpage_09153.html',
#        'At least one is connected with Ischgl, likely more',
#        'Possible duplicate since is stated as "UK confirmed case"',
#        'Possible double count: one is an existing case from NSW now counted in Victoria Statistics as is a Victoria resident',
#        'https://www.preprints.org/manuscript/202002.0399/v1',
#        'https://www.preprints.org/manuscript/202002.0399/v1',
#        'https://www.preprints.org/manuscript/202002.0399/v1',
#        'https://www.preprints.org/manuscript/202002.0399/v1',
#        'https://www.info.gov.hk/gia/general/202001/22/P2020012200982.htm',
#        'Possible double count of a case in NZ? Was confirmed in Townsville QLD',
#        'https://www.linguee.com/english-chinese/search?source=auto&query=%E8%A1%A2%E5%B7%9E%E5%B8%82',
#        'https://www.linguee.com/english-chinese/search?source=auto&query=%E8%A1%A2%E5%B7%9E%E5%B8%82',
#        "Daughter of France's 4th case (80 year-old man); also diagnosed in Paris, https://www.lexpress.fr/actualite/societe/sante/coronavirus-un-cinquieme-cas-avere-en-france-la-fille-du-quatrieme-malade_2116745.html",
#        'https://www.linguee.com/english-chinese/search?source=auto&query=%E5%84%8B%E5%B7%9E%E5%B8%82',
#        'source claims 6 total confirmed cases and also mentions 3 additional suspected cases which are not recorded here',
#        'report claims one new case, but describes total as 13, so two cases added',
#        'report claims one new case, but describes total as 13, so two cases added',
#        'https://www.google.com/maps/place/Xiangcheng+District,+Zhangzhou,+Zhangzhou,+Fujian,+China/data=!4m2!3m1!1s0x341473ad4cdfa66f:0x871c28ee5d728a22?sa=X&ved=2ahUKEwiLiemU5OPnAhWOjp4KHen7AWQQ8gEwCnoECA4QBA',
#        'https://www.google.com/maps/place/Xiangcheng+District,+Zhangzhou,+Zhangzhou,+Fujian,+China/data=!4m2!3m1!1s0x341473ad4cdfa66f:0x871c28ee5d728a22?sa=X&ved=2ahUKEwiLiemU5OPnAhWOjp4KHen7AWQQ8gEwCnoECA4QBA',
#        'https://www.google.com/maps/place/Xiangcheng+District,+Zhangzhou,+Zhangzhou,+Fujian,+China/data=!4m2!3m1!1s0x341473ad4cdfa66f:0x871c28ee5d728a22?sa=X&ved=2ahUKEwiLiemU5OPnAhWOjp4KHen7AWQQ8gEwCnoECA4QBA',
#        'https://www.info.gov.hk/gia/general/202001/23/P2020012300032.htm',
#        'https://www.info.gov.hk/gia/general/202001/25/P2020012500676.htm',
#        'https://www.google.com/maps/place/Tongnan+District,+Chongqing,+China

#        'https://www.google.com/maps/place/Tongnan+District,+Chongqing,+China/data=!4m2!3m1!1s0x36ed099f10d32783:0x4b09bc2201c96ba1?sa=X&ved=2ahUKEwjQvIzr7OPnAhXWrZ4KHWpmBKEQ8gEwC3oECBIQBA',
#        'https://www.google.com/maps/place/Tongnan+District,+Chongqing,+China/data=!4m2!3m1!1s0x36ed099f10d32783:0x4b09bc2201c96ba1?sa=X&ved=2ahUKEwjQvIzr7OPnAhXWrZ4KHWpmBKEQ8gEwC3oECBIQBA',
#        'https://www.google.com/maps/place/Bishan+District,+Chongqing,+China/data=!4m2!3m1!1s0x36ecc1a5733c679f:0x426e3870962946d1?sa=X&ved=2ahUKEwjY8dKn7ePnAhWO9Z4KHWo9AecQ8gEwC3oECBAQBA',
#        'https://www.mhlw.go.jp/stf/newpage_09099.html',
#        'Asymptomatic but placed in quarantine: https://www.thestar.com.my/news/nation/2020/01/25/three-chinese-nationals-test-positive-for-coronavirus-in-m039sia-says-health-minister#.XiwrXIRMMhs.twitter',
#        'Asymptomatic but placed in quarantine: https://www.thestar.com.my/news/nation/2020/01/25/three-chinese-nationals-test-positive-for-coronavirus-in-m039sia-says-health-minister#.XiwrXIRMMhs.twitter',
#        'Asymptomatic but placed in quarantine: https://www.thestar.com.my/news/nation/2020/01/25/three-chinese-nationals-test-positive-for-coronavirus-in-m039sia-says-health-minister#.XiwrXIRMMhs.twitter',
#        'https://laist.com/2020/01/26/coronavirus-orange-county-first-case-confirmed.php',
#        'https://www.linguee.com/english-chinese/search?source=auto&query=%E9%83%B4%E5%B7%9E%E5%B8%82',
#        'No details yet. 3 deaths as of 28.03.2020',
#        'No details yet. 3 deaths as of 28.03.2020',
#        'No details yet. 3 deaths as of 28.03.2020',
#        'No details yet. 3 deaths as of 28.03.2020',
#        'No details yet. 3 deaths as of 28.03.2020',
#        'No details yet. 3 deaths as of 28.03.2020',
#        'No details yet. 3 deaths as of 28.03.2020',
#        'No details yet. 3 deaths as of 28.03.2020',
#        'No details yet. 3 deaths as of 28.03.2020',
#        'No details yet. 3 deaths as of 28.03.2020',
#        'No details yet. 3 deaths as of 28.03.2020',
#        'No details yet. 3 deaths as of 28.03.2020',
#        'Local case. Has recovered as of 23rd April',
#        'Local case. Has recovered as of 23rd April',
#        'Angolan, Sonangol employee; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Angolan; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Angolan; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Angolan; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Ethiopian', 'Ethiopian', 'Ethiopian', 'Ethiopian', 'Ethiopian',
#        'Ethiopian', 'Ethiopian', 'Ethiopian', 'Ethiopian', 'Ethiopian',
#        'Ethiopian',
#        'Moroccan national; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Ivorian; importation=Y; transmission_type=NA; detected_through=Self-presentation',
#        'Wife of case #1; importation=N; transmission_type=Contact; detected_through=Self-presentation',
#        'Congolese; importation=Y; transmission_type=NA; detected_through=Self-presentation',
#        'Member of the Spanish Special Forces; no contact with Djibouti citizens; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Equatorial Guinean, quarantined and tested; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Equatorial Guinean, quarantined and tested; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Spanish, quarantined and tested; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Spanish, quarantined and tested; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Portuguese, quarantined and tested; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Spanish, quarantined and tested; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Congolese; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Equatoguinean woman; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        "Equatoguinean woman, first case detected in the country's Continental Region; importation=Y; transmission_type=NA; detected_through=Self-presentation",
#        'Contact of first positive case registered in the Continental Region ; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Equatorial Guinean citizen, contact of first positive case registered in the Continental Region ; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Equatorial Guinean woman, contact of first positive case registered in the Continental Region ; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'In quarantine at the Bamy hotel since arrival; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Eritrean, detected at airport; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Eritrean, detected at airport; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Eritrean, detected at airport; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Eritrean, detected at airport; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Quarantined passenger of Air Arabia; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Quarantined passenger of Air Arabia; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Contact of Case 1; contact on 3/8; border police officer at airport who checked passport of case 1; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Diabetes, hypertension; importation=Y; transmission_type=NA; detected_through=Self presentation',
#        'Togolese national; tired with fever that progressed to persistent cough; importation=Y; transmission_type=NA; detected_through=Self-presentation',
#        'Confined himself at the Hibiscus hotel in Louis then to that of the Boulevard Triomphal.; importation=Y; transmission_type=NA; detected_through=Self-presentation',
#        'Liberian, fever and unproductive cough, sought OTC treatment 3/15/2020, self-reported to National Public Health Institute ; importation=Y; transmission_type=NA; detected_through=Self-presentation',
#        'Contact of Case 1; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Was at a party in contact with recent travellers; repeatedly sought treatment at private facility starting 3/12; went to JFK hospital fever, cough, weakness vomiting, diarrhea and loss of appetite; importation=N; transmission_type=Community transmission; detected_through=Self-presentation',
#        'Malagasy; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Foreigner; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Madagascan; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Mauritian, fever; importation=Y; transmission_type=NA; detected_through=Self-presentation',
#        'Mauritian, employee on a cruise ship; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Mauritian, employee on a cruise ship; importation=Y; transmission_type=NA; detected_through=Active monitoring',
#        'Contact of case #2 (M from UK); importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Contact of case #2 (M from UK); importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Contact of case #2 (M from UK); importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Contact of case #2 (M from UK); importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Contact of case #2 (M from UK); importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Contact of case #2 (M from UK); importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Contact of case #2 (M from UK); importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Contact of case #2 (M from UK); importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Contact of case #2 (M from UK); importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Mauritian; importation=N; transmission_type=Community transmission; detected_through=Self-presentation',
#        'Contact of case #2; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Contact of case #2; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Contact of case #2; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Contact of case #2; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Contracted virus at supermarket; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'American; importation=Y; transmission_type=; detected_through=Self presentation',
#        'Congolese; importation=Y; transmission_type=; detected_through=Self presentation',
#        'Alert to authorities 3/15; importation=Y; transmission_type=; detected_through=Self-presentation',
#        'Contact of first case in Touba; importation=N; transmission_type=Contact; detected_through=Monitored',
#        'Contact of 3/11 case; importation=N; transmission_type=Contact; detected_through=Monitored',
#        'Contact of 3/17 case; importation=N; transmission_type=Contact; detected_through=Monitored',
#        'Contact; importation=N; transmission_type=Contact; detected_through=Monitored',
#        'Contact; importation=N; transmission_type=Contact; detected_through=Monitored',
#        'Contact; importation=N; transmission_type=Contact; detected_through=Monitored',
#        'Contact; importation=N; transmission_type=Contact; detected_through=Monitored',
#        'Contact; importation=N; transmission_type=Contact; detected_through=Monitored',
#        'No known contact; importation=N; transmission_type=Community transmission; detected_through=Self presentation',
#        'No known contact; importation=N; transmission_type=Community transmission; detected_through=Self presentation',
#        'No known contact; importation=N; transmission_type=Community transmission; detected_through=Self presentation',
#        'Contact of #5; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Community transmission; importation=N; transmission_type=Community transmission; detected_through=Self-presentation',
#        'Community transmission; importation=N; transmission_type=Community transmission; detected_through=Self-presentation',
#        'Community transmission; importation=N; transmission_type=Community transmission; detected_through=Self-presentation',
#        'Community transmission; importation=N; transmission_type=Community transmission; detected_through=Self-presentation',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Known contact; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Community transmission; importation=N; transmission_type=Community transmission; detected_through=Self-presentation',
#        'Wife of Ukrainian case', 'Contact',
#        'Somali; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Foreigner; detected at Aden Abdulle Intertiol Airport (Helene Compound) in Mogadisho; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Sudanese; importation=Y; transmission_type=; detected_through=Self-presentation',
#        'Sudanese; importation=Y; transmission_type=; detected_through=Self-presentation',
#        'Screened at Kilimanjaro Intertiol Airport, fell ill at hotel; importation=Y; transmission_type=; detected_through=Self presentation',
#        'German, wife of known case #3; has been self-isolating; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'High fever, poor appetite; fever detected at airport leading to monitoring; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Mandatory quarantine; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Mandatory quarantine; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Mandatory quarantine; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Mandatory quarantine; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Mandatory quarantine; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Mandatory quarantine; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Mandatory quarantine; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Mandatory quarantine; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Chinese, among those who left quarantine center; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Chinese, among those who left quarantine center; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Ugandan; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Ugandan; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Ugandan; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Symptomatic, under quarantine; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'In quarantine, usea, cough, fever; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Cough and flu, under quarantine; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Symptomatic, under quarantine; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Ugandan; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Zambian; importation=Y; transmission_type=; detected_through=Active monitoring',
#        'Contact of traveler; importation=N; transmission_type=Contact; detected_through=Active monitoring',
#        'Returned from France within the past 14 days',
#        'Permanent resident in UK but recently returned home to Kumasi',
#        'Lebanese resident in Kumasi',
#        'No travel history; Local transmission',
#        'Contact of a confirmed case at work',
#        'No travel history; Local transmission',
#        'Returned in the past 2 weeks',
#        'Guinean citizens trying to flea into Ghana',
#        'Guinean citizens trying to flea into Ghana',
#        'Guinean citizens trying to flea into Ghana',
#        'Guinean citizens trying to flea into Ghana',
#        'Guinean citizens trying to flea into Ghana',
#        'Guinean citizens trying to flea into Ghana',
#        'Guinean citizens trying to flea into Ghana',
#        'Guinean citizens trying to flea into Ghana',
#        'Guinean citizens trying to flea into Ghana',
#        'Guinean citizens trying to flea into Ghana', 'Japanese citizen',
#        'Ethiopian in close contact with first patien',
#        'Japanese national in close contact with first patient',
#        'Japanese national in close contact with first patient',
#        'UK deplomat', 'Ethiopian', 'Japanese', 'Austrialian', 'Ethiopian',
#        'Ethiopian', 'Ethiopian',
#        'quarantine at the Hosea Kutako International Airport',
#        'quarantine at the Hosea Kutako International Airport',
#        'Amsterdam from Germany on 23 February and then went to Zimbabwe on 4 March, Arrived in Namibia 13th March',
#        'American Citizen', 'Cameroonian Citizen', 'Burkina Faso Citizen',
#        'Pakistanian Citizen', 'Pakistanian Citizen',
#        'Cameroonian Citizen', 'Cameroonian Citizen',
#        'Namibia from London on 18 March',
#        'Johannesburg on 07 February 2020 and returned on 13 February 2020',
#        'studying at WITS University in South Africa. He was tested in South Africa, but travelled back before results came out.',
#        'Mauritian', 'Ethiopian', 'Ethiopian', 'Ethiopian',
#        'East African nation from Mumbai on March 8',
#        'arrived from South Sudan 06 March',
#        'arrived 8 March from Fiji via USA and Qatar',
#        'Travelled abroad - no further details',
#        'arrived in Rwanda on 15 March from London',
#        'Wife of case 3 local transmision',
#        'Arrived in Kigali on 13 March from Germany via istanbul',
#        'A Burundian who arrived in Rwanda on 15 March 2020 from Dubai. UAE in transit to Bujumbura Burundi was detected by airport medical screening personnel based on symptoms and he was then tested."',
#        'arrived in Rwanda on 8 March 2020 from Mumbai India. She is the spouse of a previously confirmed positive case',
#        'no travel history',
#        'arrived on 16 March 2020 from Belgium via Addis Ababa Ethiopia',
#        'domestic partner was previously confirmed positive along with their son aged 10 months',
#        'domestic partner was previously confirmed positive along with their son aged 10 months',
#        'who arrived from Dubai on 19 March 2020. His symptoms were detected by airport screening upon arrival and he was then tested',
#        'A Swedish man who arrived from Sweden on 3 March 2020 and reported symptoms on 18 March 2020',
#        'A Rwandan man who arrived from Sweden on 3 March 2020 and reported symptoms on 18 March 2021',
#        'Results came back on 2020-04-07 after his death',
#        'A Rwandan man who arrived from Sweden on 3 March 2020 and reported symptoms on 18 March 2022',
#        'A Rwandan man who arrived from Sweden on 3 March 2020 and reported symptoms on 18 March 2023',
#        'A Rwandan man who arrived from Sweden on 3 March 2020 and reported symptoms on 18 March 2024',
#        'Nine (9) travelers from Dubai', 'Nine (9) travelers from Dubai',
#        'Nine (9) travelers from Dubai', 'Nine (9) travelers from Dubai',
#        'Nine (9) travelers from Dubai', 'Nine (9) travelers from Dubai',
#        'Ethiopian', 'Ethiopian contact with confirmed case',
#        'Ethiopian contact with confirmed case', 'Ethiopian', 'Ethiopian',
#        'Ethiopian', 'Ethiopian contact with confirmed case',
#        'Ethiopian contact with confirmed case',
#        'Nine (9) travelers from Dubai', 'Ethiopian', 'Ethiopian',
#        'Ethiopian', 'Eritrean or Libyan', 'Libyan or Eritrean',
#        'Ethiopian contact with confirmed case', 'Ethiopian',
#        'Ethiopian first 9 months infant to be infected', 'Ethiopian',
#        'Ethiopian', 'Nine (9) travelers from Dubai', 'Ethiopian',
#        'Ethiopian', 'Ethiopian', 'Ethiopian', 'Eritrean',
#        'Nine (9) travelers from Dubai', 'Three (3) travelers from Kenya',
#        'Three (3) travelers from Kenya', 'Three (3) travelers from Kenya',
#        'Two (2) travelers from USA', 'Two (2) travelers from USA',
#        'One (1) traveler from Qatar', 'One (1) traveler from India',
#        'One (1) contact from a previously confirmed positive case identified through tracing.',
#        'Two (2) travelers from Dubai', 'Two (2) travelers from Dubai',
#        'One (1) traveler who arrived from Brussels, Belgium',
#        'One (1) contact from a previously confirmed positive case',
#        'One (1) traveler who arrived from Dubai and has been isolated',
#        'Five (5) travelers who arrived from Dubai and were isolated upon arrival',
#        'Five (5) travelers who arrived from Dubai and were isolated upon arrival',
#        'Five (5) travelers who arrived from Dubai and were isolated upon arrival',
#        'Five (5) travelers who arrived from Dubai and were isolated upon arrival',
#        'Five (5) travelers who arrived from Dubai and were isolated upon arrival',
#        'One (1) traveler who arrived from USA and was isolated upon arrival',
#        'One (1) traveler who arrived from Netherlands and who is also a contact of a previously confirmed positive traveler and has been isolated',
#        'Two (2) contacts of previously confirmed positive travelers who have been isolated',
#        'Two (2) contacts of previously confirmed positive travelers who have been isolated',
#        'One (1) traveler who arrived from Dubai and who has been isolated',
#        'One (1) traveler who arrived from USA and who has been isolated',
#        'Two (2) contacts of previously confirmed positive travelers who were detected through tracing and isolated',
#        'Two (2) contacts of previously confirmed positive travelers who were detected through tracing and isolated',
#        'studying at WITS University in South Africa. He was tested in South Africa, but travelled back before results came out',
#        'Ethiopian', 'Ethiopian', 'Ethiopian', 'Son of patient 2',
#        'Foreign national', 'Foreign national',
#        'Travelled with case 10 (001-4426)',
#        'Both travelled with case 10 (001-4426)',
#        'Was a direct contact of UK national', 'Eritrean', 'Ethiopian',
#        'Ethiopian', 'Ethiopian', 'Ethiopian', 'UK', 'Somaliland',
#        'Ethiopian', 'contact of case 11', 'contact of case 11',
#        'kept under mandatory quarantine', 'Ethiopian', 'Ethiopian',
#        'Ethiopian', 'Ethiopian', 'Ethiopian', 'Ethiopian', 'Ethiopian',
#        'Ethiopian', 'Ethiopian', 'Ethiopian', 'Ethiopian', 'Ethiopian',
#        'Ethiopian', 'Ethiopian', 'Ethiopian', 'Ethiopian', 'Ethiopian',
#        'Ethiopian', 'Ethiopian', 'Equatorial Guinea', 'Ethiopian',
#        'Ethiopian', 'Ethiopian', 'contact of case 16',
#        'contact of case 16', 'contact of case 16', 'contact of case 16',
#        'contact of case 15', 'Ethiopian', 'Ethiopian', 'Ethiopian',
#        'Chinese', 'Ethiopian', 'Ethiopian', 'Ethiopian',
#        'American (Ethiopian origin)',
#        'https://www.google.com/maps/place/Zhenlai+County,+Baicheng,+Jilin,+China/@45.9549881,122.8772653,9z/data=!3m1!4b1!4m5!3m4!1s0x5e6a4c6a8ea66823:0xfb96317ca7cfd392!8m2!3d45.847435!4d123.1998901',
#        'https://new.qq.com/omn/20200215/20200215A0LD4100.html',
#        'https://new.qq.com/omn/20200215/20200215A0LD4100.html',
#        'https://www.google.com/maps/search/%E4%BD%8F%E5%9D%80%E4%B8%BA%E9%95%BF%E6%98%A5%E5%B8%82%E9%AB%98%E6%96%B0%E5%8C%BA%E8%9E%8D%E5%88%9B%E4%B8%8A%E5%9F%8E/@43.8296097,125.2592395,16z/data=!3m1!4b1?hl=en',
#        'google.com/maps/place/Luzhou,+Sichuan,+China/@28.8805475,105.3853199,12z/data=!3m1!4b1!4m5!3m4!1s0x36ebaab481693e8d:0x57ee20f6402d239e!8m2!3d28.871569!4d105.44174',
#        'https://www.zjwjw.gov.cn/art/2020/2/3/art_1202101_41869217.html',
#        'Possible duplicate from Diamond Princess',
#        'Possible double count of Diamond Princess cases',
#        'Possible double count of Diamond Princess cases',
#        'Possible double count of Diamond Princess cases',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html Initial district extraction seems incorrect',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html Initial district extraction seems incorrect',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html Initial district extraction seems incorrect',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'http://wsjkw.cq.gov.cn/tzgg/20200127/249875.html',
#        'https://mp.weixin.qq.com/s?__biz=MjM5MTg5OTM0Ng==&mid=2651448627&idx=1&sn=e26391f0e764bfd4fc2a9a1bc15502ff&chksm=bd53ce8e8a2447985560b9a62b2a5f567693ac25032b0209cc489c49d91862fd480e4664094e&token=566312186&lang=zh_CN#rd',
#        'https://mp.weixin.qq.com/s?__biz=MjM5MTg5OTM0Ng==&mid=2651448627&idx=1&sn=e26391f0e764bfd4fc2a9a1bc15502ff&chksm=bd53ce8e8a2447985560b9a62b2a5f567693ac25032b0209cc489c49d91862fd480e4664094e&token=566312186&lang=zh_CN#rd',
#        'https://www.newsfirst.lk/2020/01/27/breaking-news-confirmed-case-of-coronavirus-in-sri-lanka/',
#        'Possible double count of a case in NZ? Was confirmed in Townsville QLD',
#        'Which countries do we indicate in travel history location?',
#        'Which countries do we indicate in travel history location?',
#        'Possible duplicate since is stated as "UK confirmed case"',
#        'https://www.info.gov.hk/gia/general/202001/22/P2020012200982.htm',
#        'https://www.info.gov.hk/gia/general/202001/23/P2020012300032.htm',
#        'https://www.info.gov.hk/gia/general/202001/25/P2020012500676.htm',
#        'Possible double count: one is an existing case from NSW now counted in Victoria Statistics as is a Victoria resident',
#        'https://www.mhlw.go.jp/stf/newpage_09153.html',
#        'https://www.linguee.com/english-chinese/search?source=auto&query=%
#        'https://laist.com/2020/01/26/coronavirus-orange-county-first-case-confirmed.php',
#        'Most details from listening to LA County Public Health Dept Press Conference live',
#        'https://www.cbc.ca/news/canada/british-columbia/bc-coronavirus-flight-montreal-vancouver-1.5473283'],
#       dtype=object)

# %% [markdown]
# <h3>Lots and lots of text! Not useful at the moment for the scope of this project. This column can be dropped.

# %%
# Dropping the notes column:
covid_df_clean = covid_df_clean.drop(["notes_for_discussion"], axis=1)

# %%
# Review the remaining columns to see what else we can get rid of:
covid_df_clean.columns
# Out:
# Index(['ID', 'age', 'sex', 'city', 'province', 'country',
#        'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation',
#        'symptoms', 'lives_in_Wuhan', 'travel_history_dates',
#        'travel_history_location', 'reported_market_exposure',
#        'additional_information', 'chronic_disease_binary', 'chronic_disease',
#        'source', 'sequence_available', 'outcome', 'date_death_or_discharge',
#        'location', 'country_new', 'travel_history_binary'],
#       dtype='object')

# %% [markdown]
# <h3>The fact that we have a "country" column and a "country_new" column is strange. I will explore what makes them different and which one should be droppped:

# %%
# Let's see what information between the country and country_new columns is different:
# Start by getting both of the columns by themselves from the original dataframe into a new dataframe "country_df" and
# dropping any NaN values:
country_df = covid_df[["country","country_new"]].dropna()
#Return a dataframe that shows only the rows where the two columns differ:
country_df[country_df.country != country_df.country_new]
# Out:
#         country country_new
# 87313   Algeria     Algiers
# 87324   Algeria     Algiers
# 87335   Algeria     Algiers
# 87346   Algeria     Algiers
# 87358   Algeria     Algiers
# ...         ...         ...
# 101825  Algeria     Algiers
# 574547  Ecuador     Ecuadar
# 575702  Ecuador     Ecuadar
# 576279  Ecuador     Ecuadar
# 616480  Ecuador     Ecuadar
#
# [185 rows x 2 columns]

# %% [markdown]
# <h3>At first glance, it seems like the only difference is that country_new has errors in spelling "Ecuador" and that it says "Algiers" (not a country!) instead of "Alegeria." I think we can get rid of country_new, then.

# %%
# Drop the "country_new" column:
covid_df_clean = covid_df_clean.drop("country_new", axis=1)

# %%
covid_df_clean.columns
# Out:
# Index(['ID', 'age', 'sex', 'city', 'province', 'country',
#        'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation',
#        'symptoms', 'lives_in_Wuhan', 'travel_history_dates',
#        'travel_history_location', 'reported_market_exposure',
#        'additional_information', 'chronic_disease_binary', 'chronic_disease',
#        'source', 'sequence_available', 'outcome', 'date_death_or_discharge',
#        'location', 'travel_history_binary'],
#       dtype='object')

# %%
symptoms = covid_df.symptoms
symptoms.dropna(inplace=True)
symptoms.values
# Out:
# array(['fever, severe pneumonia', 'fever', 'cough, fever, sore throat',
#        ..., 'cough, fever, nausea', 'cough', 'mild'], dtype=object)

# %%
country_df[country_df.country != country_df.country_new].values
# Out:
# array([['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Algeria', 'Algiers'],
#        ['Ecuador', 'Ecuadar'],
#        ['Ecuador', 'Ecuadar'],
#        ['Ecuador', 'Ecuadar'],
#        ['Ecuador', 'Ecuadar']], dtype=object)
